# %%
import pandas as pd

# %%
q2_unclassified = pd.read_excel('q2_unclassified.xlsx')

# %%
q2_unclassified.head()
# Out:
#          Area Name    Year         Quarter  No Of Establishments  Employment  \
# 0  Anderson County  2017.0  Second Quarter                  32.0        70.0
# 1   Andrews County  2017.0  Second Quarter                   2.0         1.0
# 2  Angelina County  2017.0  Second Quarter                   3.0         5.0
# 3   Aransas County  2017.0  Second Quarter                   8.0        16.0
# 4  Atascosa County  2017.0  Second Quarter                   7.0        13.0
#
#    One-Year Employment Gain/Loss (Percent)  Average Weekly Wages  \
# 0                                    159.3                 822.0
# 1                                    -50.0                1059.0
# 2                                      NaN                 529.0
# 3                                    700.0                 501.0
# 4                                     85.7                 555.0
#
#    On-Year Weekly Wages Gain/Loss (Percent)      Industry     FIPS USPS
# ...

# %%
q2_other = pd.read_excel('q2_other.xlsx')

# %%
q2_other.head()
# Out:
#          Area Name    Year         Quarter  No Of Establishments  Employment  \
# 0  Anderson County  2017.0  Second Quarter                  96.0       561.0
# 1   Andrews County  2017.0  Second Quarter                  34.0       198.0
# 2  Angelina County  2017.0  Second Quarter                 141.0       735.0
# 3   Aransas County  2017.0  Second Quarter                  49.0       213.0
# 4    Archer County  2017.0  Second Quarter                  11.0        44.0
#
#    One-Year Employment Gain/Loss (Percent)  Average Weekly Wages  \
# 0                                      4.5                 719.0
# 1                                      0.0                 892.0
# 2                                     -0.3                 562.0
# 3                                    -10.1                 639.0
# 4                                    -17.0                 661.0
#
#    On-Year Weekly Wages Gain/Loss (Percent)        Industry     FIPS USPS
# ...

# %%
q2_leisure_hospitality = pd.read_excel('q2_leisure_hospitality.xlsx')
q2_education_health = pd.read_excel('q2_education_health.xlsx')
q2_prof_business = pd.read_excel('q2_prof_business.xlsx')
q2_finance = pd.read_excel('q2_finance.xlsx')
q2_information = pd.read_excel('q2_information.xlsx')
q2_trade_trans_ut = pd.read_excel('q2_trade_trans_ut.xlsx')
q2_manufacturing = pd.read_excel('q2_manufacturing.xlsx')
q2_construction = pd.read_excel('q2_construction.xlsx')
q2_natural_res_mining = pd.read_excel('q2_natural_res_mining.xlsx')

# %%
# q2_unclassified['Industry'] = 'Unclassified'
# q2_other['Industry'] = 'Other'
# q2_leisure_hospitality['Industry'] = 'Hospitality'
# q2_education_health['Industry'] = 'Education_Health'
# q2_prof_business['Industry'] = 'Prof_Business'
# q2_finance['Industry'] = 'Financial Activities'
# q2_information['Industry'] = 'Information'
# q2_trade_trans_ut['Industry'] = 'Trade, Transportation, and Utilities'
# q2_manufacturing['Industry'] = 'Manufacturing'
# q2_construction['Industry'] = 'Construction'
# q2_natural_res_mining['Industry'] = 'Natural Resources and Mining'

# %%
list_of_dfs = [q2_leisure_hospitality, q2_education_health, q2_prof_business, q2_finance, q2_information, q2_trade_trans_ut, q2_manufacturing, q2_construction, q2_natural_res_mining, q2_unclassified, q2_other    ]

# %%
q2_df = pd.concat(list_of_dfs)

# %%
q2_df['Area Name'].value_counts()
# Out:
# Eastland County        11
# Gonzales County        11
# Rusk County            11
# Wichita County         11
# Palo Pinto County      11
# Tyler County           11
# Polk County            11
# Bell County            11
# Llano County           11
# Nolan County           11
# Deaf Smith County      11
# Andrews County         11
# Cass County            11
# Lamar County           11
# Dallam County          11
# Stephens County        11
# San Jacinto County     11
# Liberty County         11
# Kleberg County         11
# Shackelford County     11
# Hemphill County        11
# Hill County            11
# Hardin County          11
# Jefferson County       11
# Gray County            11
#                        11
# Gaines County          11
# Medina County          11
# Austin County          11
# Wood County            11
#                        ..
# Zapata County          10
# Oldham County          10
# Hamilton County        10
# Baylor County          10
# ...

# %%
q2_df.to_csv('q2_df.csv')

# %%
q2_df.head()
# Out:
#          Area Name    Year         Quarter  No Of Establishments  Employment  \
# 0  Anderson County  2017.0  Second Quarter                 109.0      1666.0
# 1   Andrews County  2017.0  Second Quarter                  37.0       531.0
# 2  Angelina County  2017.0  Second Quarter                 157.0      3549.0
# 3   Aransas County  2017.0  Second Quarter                 124.0      1660.0
# 4    Archer County  2017.0  Second Quarter                   8.0        60.0
#
#    One-Year Employment Gain/Loss (Percent)  Average Weekly Wages  \
# 0                                      3.1                 275.0
# 1                                     17.5                 439.0
# 2                                      7.6                 302.0
# 3                                      6.8                 335.0
# 4                                     50.0                 222.0
#
#    On-Year Weekly Wages Gain/Loss (Percent)                 Industry     FIPS  \
# ...

# %%
q2_df.tail()
# Out:
#          Area Name    Year         Quarter  No Of Establishments  Employment  \
# 249  Yoakum County  2017.0  Second Quarter                  14.0        87.0
# 250   Young County  2017.0  Second Quarter                  43.0       122.0
# 251  Zapata County  2017.0  Second Quarter                   9.0        31.0
# 252  Zavala County  2017.0  Second Quarter                  11.0         NaN
# 253                    NaN             NaN                   NaN         NaN
#
#      One-Year Employment Gain/Loss (Percent)  Average Weekly Wages  \
# 249                                      3.6                 808.0
# 250                                    -10.9                 585.0
# 251                                      NaN                 275.0
# 252                                      NaN                   NaN
# 253                                      NaN                   NaN
#
#      On-Year Weekly Wages Gain/Loss (Percent)        Industry     FIPS USPS
# ...

# %%
q2_df.drop(index=253, inplace=True)

# %%
q2_df.tail()
# Out:
#          Area Name    Year         Quarter  No Of Establishments  Employment  \
# 248    Wood County  2017.0  Second Quarter                  60.0       310.0
# 249  Yoakum County  2017.0  Second Quarter                  14.0        87.0
# 250   Young County  2017.0  Second Quarter                  43.0       122.0
# 251  Zapata County  2017.0  Second Quarter                   9.0        31.0
# 252  Zavala County  2017.0  Second Quarter                  11.0         NaN
#
#      One-Year Employment Gain/Loss (Percent)  Average Weekly Wages  \
# 248                                     25.0                 529.0
# 249                                      3.6                 808.0
# 250                                    -10.9                 585.0
# 251                                      NaN                 275.0
# 252                                      NaN                   NaN
#
#      On-Year Weekly Wages Gain/Loss (Percent)        Industry     FIPS USPS
# ...

# %%
q2_df.drop(columns = ['USPS', 'Year'], inplace=True)

# %%
q2_df.to_csv('q2_df.csv')

# %%
q2_df.shape
# Out:
# (2705, 9)
