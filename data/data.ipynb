# %%
import pandas as pd
import numpy as np

# %%
# load all the data from q4
con = pd.read_csv('../data/BLS_Data_Q4_17/q4_2017_construction.csv')
edu = pd.read_csv('../data/BLS_Data_Q4_17/q4_2017_education_health.csv')
fin = pd.read_csv('../data/BLS_Data_Q4_17/q4_2017_financial_activities.csv')
inf = pd.read_csv('../data/BLS_Data_Q4_17/q4_2017_information.csv')
hosp = pd.read_csv('../data/BLS_Data_Q4_17/q4_2017_leisure_hodpitality.csv')
manf = pd.read_csv('../data/BLS_Data_Q4_17/q4_2017_manufacturing.csv')
nat = pd.read_csv('../data/BLS_Data_Q4_17/q4_2017_natural_resources.csv')
other = pd.read_csv('../data/BLS_Data_Q4_17/q4_2017_other_services.csv')
prof = pd.read_csv('../data/BLS_Data_Q4_17/q4_2017_professional_buessiness_service.csv')
trd = pd.read_csv('../data/BLS_Data_Q4_17/q4_2017_trade_transportation.csv')
unc = pd.read_csv('../data/BLS_Data_Q4_17/q4_2017_unclassified.csv')

# %%
# create a list for all the data
list_of_df = [con,edu,fin,inf,hosp,manf,nat,other,prof,trd,unc]

# %%
q4_df = pd.concat(list_of_df)

# %%
q4_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2735 entries, 0 to 235
# Data columns (total 11 columns):
# Area Name                                   2735 non-null object
# Year                                        2724 non-null float64
# Quarter                                     2724 non-null object
# No Of Establishments                        2724 non-null float64
# Employment                                  2373 non-null float64
# One-Year Employment Gain/Loss (Percent)     2254 non-null float64
# Average Weekly Wages                        2373 non-null float64
# On-Year Weekly Wages Gain/Loss (Percent)    2255 non-null float64
# Industry                                    2724 non-null object
# FIPS                                        2724 non-null float64
# USPS                                        2724 non-null object
# dtypes: float64(7), object(4)
# memory usage: 256.4+ KB

# %%
q4_df.head()
# Out:
#          Area Name    Year         Quarter  No Of Establishments  Employment  \
# 0  Anderson County  2017.0  Fourth Quarter                 106.0       607.0
# 1   Andrews County  2017.0  Fourth Quarter                  37.0       821.0
# 2  Angelina County  2017.0  Fourth Quarter                 147.0      1369.0
# 3   Aransas County  2017.0  Fourth Quarter                  67.0       369.0
# 4    Archer County  2017.0  Fourth Quarter                  36.0       119.0
#
#    One-Year Employment Gain/Loss (Percent)  Average Weekly Wages  \
# 0                                    -12.8                 939.0
# 1                                      9.8                1575.0
# 2                                     -8.7                 856.0
# 3                                     -3.1                 979.0
# 4                                      0.8                 670.0
#
#    On-Year Weekly Wages Gain/Loss (Percent)      Industry     FIPS USPS
# ...

# %%
q4_df.drop(columns = ['USPS','Year'],index = 235,inplace = True)

# %%
q4_df.to_csv('./BLS_Data_Q4_17/q4_df.csv')

# %%
# load the q4_df
q4_df1 = pd.read_csv('./BLS_Data_Q4_17/q4_df.csv')

# %%
q4_df1.head(2)
# Out:
#    Unnamed: 0        Area Name         Quarter  No Of Establishments  \
# 0           0  Anderson County  Fourth Quarter                 106.0
# 1           1   Andrews County  Fourth Quarter                  37.0
#
#    Employment  One-Year Employment Gain/Loss (Percent)  Average Weekly Wages  \
# 0       607.0                                    -12.8                 939.0
# 1       821.0                                      9.8                1575.0
#
#    On-Year Weekly Wages Gain/Loss (Percent)      Industry     FIPS
# 0                                      27.2  Construction  48001.0
# 1                                      12.7  Construction  48003.0

# %%
q4_df1.to_csv('./BLS_Data_Q4_17/q4_df.csv')

# %%
q2 = pd.read_csv('./BLS_Data_Q2_17/q2_df.csv')
q3 = pd.read_csv('./BLS_Data_Q3_17/q3_df.csv')
q4 = pd.read_csv('./BLS_Data_Q4_17/q4_df.csv')

# %%
# merge the data
df = pd.concat([q2,q3,q4])
df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#          Area Name  Average Weekly Wages  Employment     FIPS  \
# 0  Anderson County                 275.0      1666.0  48001.0
# 1   Andrews County                 439.0       531.0  48003.0
# 2  Angelina County                 302.0      3549.0  48005.0
# 3   Aransas County                 335.0      1660.0  48007.0
# 4    Archer County                 222.0        60.0  48009.0
#
#                   Industry  No Of Establishments  \
# 0  Leisure and Hospitality                 109.0
# 1  Leisure and Hospitality                  37.0
# 2  Leisure and Hospitality                 157.0
# 3  Leisure and Hospitality                 124.0
# ...

# %%
df = df.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1'])

# %%
df.head()
# Out:
#          Area Name  Average Weekly Wages  Employment     FIPS  \
# 0  Anderson County                 275.0      1666.0  48001.0
# 1   Andrews County                 439.0       531.0  48003.0
# 2  Angelina County                 302.0      3549.0  48005.0
# 3   Aransas County                 335.0      1660.0  48007.0
# 4    Archer County                 222.0        60.0  48009.0
#
#                   Industry  No Of Establishments  \
# 0  Leisure and Hospitality                 109.0
# 1  Leisure and Hospitality                  37.0
# 2  Leisure and Hospitality                 157.0
# 3  Leisure and Hospitality                 124.0
# 4  Leisure and Hospitality                   8.0
#
#    On-Year Weekly Wages Gain/Loss (Percent)  \
# 0                                       1.1
# 1                                      -0.9
# 2                                      -0.3
# 3                                      -0.9
# 4                                     -21.3
#
# ...

# %%
# save the data 
df.to_csv('../data/q2_q3_q4.csv')
