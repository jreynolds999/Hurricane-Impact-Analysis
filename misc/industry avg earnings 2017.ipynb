# %% [markdown]
# # Read in all dataframes

# %%
import pandas as pd

# %%
q3_manufacturing = pd.read_csv('bls_q3_manufacturing.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-c0610f9636b4> in <module>
# ----> 1 q3_manufacturing = pd.read_csv('bls_q3_manufacturing.csv')
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
q3_construction = pd.read_csv('./BLS_Data_Q3_17/bls_q3_construction.csv')

# %%
q3_education = pd.read_csv('./BLS_Data_Q3_17/bls_q3_education.csv')

# %%
q3_financial = pd.read_csv('./BLS_Data_Q3_17/bls_q3_financial.csv')

# %%
q3_leisure = pd.read_csv('./BLS_Data_Q3_17/bls_q3_leisure.csv')

# %%
q3_information = pd.read_csv('./BLS_Data_Q3_17/bls_q3_information.csv')

# %%
q3_nat_res_mining = pd.read_csv('./BLS_Data_Q3_17/bls_q3_nat_res_mining.csv')

# %%
q3_other_services = pd.read_csv('./BLS_Data_Q3_17/bls_q3_other_services.csv')

# %%
q3_trade_transpo_util = pd.read_csv('./BLS_Data_Q3_17/bls_q3_trade_transpo_utilities.csv')

# %%
q3_unclassified= pd.read_csv('./BLS_Data_Q3_17/bls_q3_unclassified.csv')

# %%
q3_professional = pd.read_csv('./BLS_Data_Q3_17/bls_q3_professional.csv')

# %%
df_list = [q3_manufacturing, q3_construction, q3_education,
           q3_financial, q3_leisure, q3_information,
           q3_nat_res_mining, q3_other_services, q3_trade_transpo_util, q3_unclassified, q3_professional]

# %%
q3_df = pd.concat(df_list)

# %%
q3_df.drop(columns= ['USPS', 'Year'], index=254,inplace=True)

# %%
q3_df.to_csv('./BLS_Data_Q3_17/q3_df.csv')

# %%
q3_df = pd.read_csv('./BLS_Data_Q3_17/q3_df.csv')

# %%
q3_df
# Out:
#       Unnamed: 0          Area Name        Quarter  No Of Establishments  \
# 0              0    Anderson County  Third Quarter                  55.0
# 1              1     Andrews County  Third Quarter                  11.0
# 2              2    Angelina County  Third Quarter                  73.0
# 3              3     Aransas County  Third Quarter                  18.0
# 4              4      Archer County  Third Quarter                   4.0
# 5              5   Armstrong County  Third Quarter                   1.0
# 6              6    Atascosa County  Third Quarter                  32.0
# 7              7      Austin County  Third Quarter                  65.0
# 8              8      Bailey County  Third Quarter                   8.0
# 9              9     Bandera County  Third Quarter                  12.0
# 10            10     Bastrop County  Third Quarter                  75.0
# 11            11      Baylor County  Third Quarter                   2.0
# ...
