# %%
import pandas as pd

# %%
hazard_mitigation_df = pd.read_csv('./data/HazardMitigationAssistanceMitigatedProperties.csv')

# %%
hazard_mitigation_df.drop(columns=['stateNumberCode','countyCode', 'projectIdentifier', 'propertyAction', 'structureType'], inplace= True)

# %%
accepted_ hazard_mitigation_df[hazard_mitigation_df['status'] == 'Approved']
# Out:
#        disasterNumber  region           state              county  \
# 0              4116.0     5.0        Illinois                Cook
# 3              4086.0     2.0      New Jersey               Ocean
# 7              4274.0     6.0        Oklahoma            Garfield
# 9              4237.0     8.0    South Dakota       Oglala Lakota
# 16             1731.0     9.0      California           El Dorado
# 20             1971.0     4.0         Alabama              Marion
# 26             1971.0     4.0         Alabama              Walker
# 29             4285.0     4.0  North Carolina               Wayne
# 31             4285.0     4.0  North Carolina           Edgecombe
# 33             1792.0     6.0       Louisiana           Calcasieu
# 34             1971.0     4.0         Alabama              Marion
# 35             1539.0     4.0         Florida          Santa Rosa
# 45             1831.0     4.0         Florida            Escambia
# ...
